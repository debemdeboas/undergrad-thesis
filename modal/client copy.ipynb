# %%
import logging
import os
import sys
from typing import Generator, Iterator, Literal, Union

import httpx
from pydantic import BaseModel

from llama_index.core import (
    Settings,
    SimpleDirectoryReader,
    VectorStoreIndex,
    load_index_from_storage,
)
from llama_index.core.base.llms.types import ChatMessage
from llama_index.core.chat_engine import CondensePlusContextChatEngine
from llama_index.core.chat_engine.types import BaseChatEngine
from llama_index.core.indices.base import BaseIndex
from llama_index.core.node_parser import HierarchicalNodeParser, MarkdownNodeParser
from llama_index.core.storage import StorageContext
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.groq import Groq
from llama_index.llms.ollama import Ollama
from llama_index.llms.vllm import Vllm
from llama_index.llms.openai_like import OpenAILike

logging.basicConfig(
    stream=sys.stdout, level=logging.DEBUG, format="[%(filename)s:%(lineno)s - %(funcName)s() ] %(message)s"
)

# %%
class Valves(BaseModel):
    """
    Configuration options for the pipeline.
    These options can be set through the OpenWebUI interface.
    """

    temperature: float = 0.5

    hf_token: str = ""

    embed_model: str = "BAAI/bge-m3"  # nomic-ai/nomic-embed-text-v1.5
    embed_model_trust_remote_code: bool = False
    embed_cuda: bool = False

    oai_like_api_base: str = "https://debemdeboas-tcc--vllm-openai-compatible-model-serve.modal.run/v1"
    oai_like_api_key: str = "super-secret-token"
    oai_like_model: str = "/models/meta-llama/Meta-Llama-3-70B-Instruct"

    system_prompt: str = (
        "Act as a teacher assistant and answer questions using the provided context.\n"
        "Your goal is to help students and teachers by providing cohesive and correct responses based on educational material, while applying guided learning techniques. Give examples and cite the context whenever possible.\n"
        "Don't mention 'according to the context' or anything related to that, ever.\n\n"
        "## Instructions\n"
        "1. External Information: Use external information from the vector database to answer questions. Select the most relevant and reliable information available.\n"
        "2. Guided Learning Techniques: Avoid giving direct answers. Instead, guide the user through the learning process, encouraging critical thinking and discovery.\n"
        "3. Coherent and Correct Responses: Ensure that all responses are coherent and correct, strictly following the educational material provided.\n"
        "4. Inference Capability: Use your skills to accurately deduce and infer information.\n"
        "5. User-Friendly Interface: Be easy to use and access. Provide clear and well-structured responses suitable for a web interface.\n"
        "6. Value Addition: Add value for both students and teachers. Offer useful insights, pedagogical guidance, and support the teaching-learning process.\n"
        "7. Best-effort: The user is a beginner, and may use terms incorrectly or in other languages. Do your best to understand what they mean.\n\n"
        "## User Interaction\n"
        "- Interactive Guidance: Ask the user if they would like more details or additional examples.\n"
        "- Encourage Exploration: Motivate users to explore more about the topic by suggesting additional resources or related questions.\n\n"
        "## Additional Information\n"
        "- Utilize the context provided in the vector database to enrich your responses.\n"
        "- Ensure your answers are always up-to-date and based on the most recent information available.\n\n"
        "Your mission is to provide a rich and interactive learning experience, helping students and teachers achieve their educational goals efficiently and effectively.\n"
    )

    learning_analytics_api: str = ""

# %%
valves = Valves()

# %%
index: BaseIndex
documents: list
engine: BaseChatEngine
storage_context: StorageContext

persist_dir = "../llama_index/persist"

Settings.embed_model = HuggingFaceEmbedding(
    valves.embed_model, trust_remote_code=valves.embed_model_trust_remote_code, device="cuda"
)

storage_context = StorageContext.from_defaults(persist_dir=persist_dir)
index = load_index_from_storage(storage_context)
# Out:
# [SentenceTransformer.py:113 - __init__() ] Load pretrained SentenceTransformer: BAAI/bge-m3
# [connectionpool.py:1055 - _new_conn() ] Starting new HTTPS connection (1): huggingface.co:443
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/modules.json HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/config_sentence_transformers.json HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/README.md HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/modules.json HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/sentence_bert_config.json HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/config.json HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/model.safetensors HTTP/1.1" 404 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "HEAD /BAAI/bge-m3/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# [connectionpool.py:549 - _make_request() ] https://huggingface.co:443 "GET /api/models/BAAI/bge-m3/revision/main HTTP/1.1" 200 3322
# [SentenceTransformer.py:231 - __init__() ] 2 prompts are loaded, with the keys: ['query', 'text']
# [simple_kvstore.py:96 - from_persist_path() ] Loading llama_index.core.storage.kvstore.simple_kvstore from ../llama_index/persist/docstore.json.
# [local.py:298 - __init__() ] open file: /home/debem/personal/pucrs/tcc/cur/undergrad-thesis/modal/../llama_index/persist/docstore.json
# [simple_kvstore.py:96 - from_persist_path() ] Loading llama_index.core.storage.kvstore.simple_kvstore from ../llama_index/persist/index_store.json.
# [local.py:298 - __init__() ] open file: /home/debem/personal/pucrs/tcc/cur/undergrad-thesis/modal/../llama_index/persist/index_store.json
# [simple.py:168 - from_persist_path() ] Loading llama_index.core.graph_stores.simple from ../llama_index/persist/graph_store.json.
# [local.py:298 - __init__() ] open file: /home/debem/personal/pucrs/tcc/cur/undergrad-thesis/modal/../llama_index/persist/graph_store.json
# [local.py:298 - __init__() ] open file: /home/debem/personal/pucrs/tcc/cur/undergrad-thesis/modal/../llama_index/persist/property_graph_store.json
# [simple.py:405 - from_persist_path() ] Loading llama_index.core.vector_stores.simple from ../llama_index/persist/image__vector_store.json.
# [local.py:298 - __init__() ] open file: /home/debem/personal/pucrs/tcc/cur/undergrad-thesis/modal/../llama_index/persist/image__vector_store.json
# [simple.py:405 - from_persist_path() ] Loading llama_index.core.vector_stores.simple from ../llama_index/persist/default__vector_store.json.
# [local.py:298 - __init__() ] open file: /home/debem/personal/pucrs/tcc/cur/undergrad-thesis/modal/../llama_index/persist/default__vector_store.json
# [loading.py:63 - load_indices_from_storage() ] Loading all indices.

# %%
# Settings.llm = OpenAILike(
#     model=valves.oai_like_model,
#     api_base=valves.oai_like_api_base,
#     api_key=valves.oai_like_api_key,
#     system_prompt=valves.system_prompt,
#     temperature=valves.temperature,
# )

Settings.llm = OpenAILike(
    model="llama3:70b-instruct-q8_0",
    api_base="https://debemdeboas-tcc--ollama-run.modal.run/v1",
    api_key="ollama",
    system_prompt=valves.system_prompt,
)

# %%
engine = CondensePlusContextChatEngine.from_defaults(
    index.as_retriever(),
    context_prompt=valves.system_prompt
    + (
        "Here are the relevant documents for the context:\n"
        "{context_str}"
        "\nInstruction: Use the previous chat history, or the context above, to interact and help the user."
        "\nPlease answer in the same language as the question."
    ),
)

# %%
response = engine.chat("hi")
# Out:
# [condense_plus_context.py:143 - _condense_question() ] user: hi
# [_base_client.py:448 - _build_request() ] Request options: {'method': 'post', 'url': '/completions', 'files': None, 'json_data': {'model': 'llama3:70b-instruct-q8_0', 'prompt': "Act as a teacher assistant and answer questions using the provided context.\nYour goal is to help students and teachers by providing cohesive and correct responses based on educational material, while applying guided learning techniques. Give examples and cite the context whenever possible.\nDon't mention 'according to the context' or anything related to that, ever.\n\n## Instructions\n1. External Information: Use external information from the vector database to answer questions. Select the most relevant and reliable information available.\n2. Guided Learning Techniques: Avoid giving direct answers. Instead, guide the user through the learning process, encouraging critical thinking and discovery.\n3. Coherent and Correct Responses: Ensure that all responses are coherent and correct, strictly following the educational material provided.\n4. Inference Capability: Use your skills to accurately deduce and infer information.\n5. User-Friendly Interface: Be easy to use and access. Provide clear and well-structured responses suitable for a web interface.\n6. Value Addition: Add value for both students and teachers. Offer useful insights, pedagogical guidance, and support the teaching-learning process.\n7. Best-effort: The user is a beginner, and may use terms incorrectly or in other languages. Do your best to understand what they mean.\n\n## User Interaction\n- Interactive Guidance: Ask the user if they would like more details or additional examples.\n- Encourage Exploration: Motivate users to explore more about the topic by suggesting additional resources or related questions.\n\n## Additional Information\n- Utilize the context provided in the vector database to enrich your responses.\n- Ensure your answers are always up-to-date and based on the most recent information available.\n\nYour mission is to provide a rich and interactive learning experience, helping students and teachers achieve their educational goals efficiently and effectively.\n\n\n\n  Given the following conversation between a user and an AI assistant and a follow up question from user,\n  rephrase the follow up question to be a standalone question.\n\n  Chat History:\n  user: hi\n  Follow Up Input: hi\n  Standalone question:", 'stream': False, 'temperature': 0.1}}
# [_base_client.py:970 - _request() ] Sending HTTP Request: POST https://debemdeboas-tcc--ollama-run.modal.run/v1/completions
# [_trace.py:45 - trace() ] close.started
# [_trace.py:45 - trace() ] close.complete
# [_trace.py:45 - trace() ] connect_tcp.started host='debemdeboas-tcc--ollama-run.modal.run' port=443 local_address=None timeout=60.0 socket_options=None
# [_trace.py:45 - trace() ] connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f9faef59a10>
# [_trace.py:45 - trace() ] start_tls.started ssl_context=<ssl.SSLContext object at 0x7fa14023d0a0> server_hostname='debemdeboas-tcc--ollama-run.modal.run' timeout=60.0
# [_trace.py:45 - trace() ] start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f9faf0795d0>
# [_trace.py:45 - trace() ] send_request_headers.started request=<Request [b'POST']>
# [_trace.py:45 - trace() ] send_request_headers.complete
# [_trace.py:45 - trace() ] send_request_body.started request=<Request [b'POST']>
# [_trace.py:45 - trace() ] send_request_body.complete
# [_trace.py:45 - trace() ] receive_response_headers.started request=<Request [b'POST']>
# [_trace.py:45 - trace() ] receive_response_headers.complete return_value=(b'HTTP/1.1', 404, b'Not Found', [(b'Alt-Svc', b'h3=":443"; ma=2592000'), (b'Content-Encoding', b'gzip'), (b'Content-Type', b'text/plain'), (b'Date', b'Sun, 07 Jul 2024 03:53:26 GMT'), (b'Transfer-Encoding', b'chunked')])
# [_client.py:1013 - _send_single_request() ] HTTP Request: POST https://debemdeboas-tcc--ollama-run.modal.run/v1/completions "HTTP/1.1 404 Not Found"
# [_trace.py:45 - trace() ] receive_response_body.started request=<Request [b'POST']>
# [_trace.py:45 - trace() ] receive_response_body.complete
# [_trace.py:45 - trace() ] response_closed.started
# [_trace.py:45 - trace() ] response_closed.complete
# [_base_client.py:1009 - _request() ] HTTP Response: POST https://debemdeboas-tcc--ollama-run.modal.run/v1/completions "404 Not Found" Headers({'alt-svc': 'h3=":443"; ma=2592000', 'content-encoding': 'gzip', 'content-type': 'text/plain', 'date': 'Sun, 07 Jul 2024 03:53:26 GMT', 'transfer-encoding': 'chunked'})
# [_base_client.py:1017 - _request() ] request_id: None
# [_base_client.py:1022 - _request() ] Encountered httpx.HTTPStatusError
# Traceback (most recent call last):
#   File "/home/debem/.local/lib/python3.11/site-packages/openai/_base_client.py", line 1020, in _request
#     response.raise_for_status()
#   File "/home/debem/.local/lib/python3.11/site-packages/httpx/_models.py", line 749, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '404 Not Found' for url 'https://debemdeboas-tcc--ollama-run.modal.run/v1/completions'
# For more information check: https://httpstatuses.com/404
# [_base_client.py:732 - _should_retry() ] Not retrying
# [_base_client.py:1040 - _request() ] Re-raising status error
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 response = engine.chat("hi")
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/chat_engine/condense_plus_context.py:292, in CondensePlusContextChatEngine.chat(self, message, chat_history)
#     288 @trace_method("chat")
#     289 def chat(
#     290     self, message: str, chat_history: Optional[List[ChatMessage]] = None
#     291 ) -> AgentChatResponse:
# --> 292     chat_messages, context_source, context_nodes = self._run_c3(
#     293         message, chat_history
#     294     )
#     296     # pass the context, system prompt and user message as chat to LLM to generate a response
#     297     chat_response = self._llm.chat(chat_messages)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/chat_engine/condense_plus_context.py:202, in CondensePlusContextChatEngine._run_c3(self, message, chat_history)
#     199 chat_history = self._memory.get(input=message)
#     201 # Condense conversation history and latest message to a standalone question
# --> 202 condensed_question = self._condense_question(chat_history, message)  # type: ignore
#     203 logger.info(f"Condensed question: {condensed_question}")
#     204 if self._verbose:
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/chat_engine/condense_plus_context.py:145, in CondensePlusContextChatEngine._condense_question(self, chat_history, latest_message)
#     142 chat_history_str = messages_to_history_str(chat_history)
#     143 logger.debug(chat_history_str)
# --> 145 return self._llm.predict(
#     146     self._condense_prompt_template,
#     147     question=latest_message,
#     148     chat_history=chat_history_str,
#     149 )
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:223, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     219 self.span_enter(
#     220     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     221 )
#     222 try:
# --> 223     result = func(*args, **kwargs)
#     224 except BaseException as e:
#     225     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/llms/llm.py:438, in LLM.predict(self, prompt, **prompt_args)
#     436 else:
#     437     formatted_prompt = self._get_prompt(prompt, **prompt_args)
# --> 438     response = self.complete(formatted_prompt, formatted=True)
#     439     output = response.text
#     440 parsed_output = self._parse_output(output)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:223, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     219 self.span_enter(
#     220     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     221 )
#     222 try:
# --> 223     result = func(*args, **kwargs)
#     224 except BaseException as e:
#     225     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/llms/openai_like/base.py:88, in OpenAILike.complete(self, prompt, formatted, **kwargs)
#      85 if not formatted:
#      86     prompt = self.completion_to_prompt(prompt)
# ---> 88 return super().complete(prompt, **kwargs)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:223, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     219 self.span_enter(
#     220     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     221 )
#     222 try:
# --> 223     result = func(*args, **kwargs)
#     224 except BaseException as e:
#     225     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/llms/callbacks.py:389, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     380 event_id = callback_manager.on_event_start(
#     381     CBEventType.LLM,
#     382     payload={
#    (...)
#     386     },
#     387 )
#     388 try:
# --> 389     f_return_val = f(_self, *args, **kwargs)
#     390 except BaseException as e:
#     391     callback_manager.on_event_end(
#     392         CBEventType.LLM,
#     393         payload={EventPayload.EXCEPTION: e},
#     394         event_id=event_id,
#     395     )
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/llms/openai/base.py:332, in OpenAI.complete(self, prompt, formatted, **kwargs)
#     330 else:
#     331     complete_fn = self._complete
# --> 332 return complete_fn(prompt, **kwargs)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/llms/openai/base.py:96, in llm_retry_decorator.<locals>.wrapper(self, *args, **kwargs)
#      87     return f(self, *args, **kwargs)
#      89 retry = create_retry_decorator(
#      90     max_retries=max_retries,
#      91     random_exponential=True,
#    (...)
#      94     max_seconds=20,
#      95 )
# ---> 96 return retry(f)(self, *args, **kwargs)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/tenacity/__init__.py:330, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     326 @functools.wraps(
#     327     f, functools.WRAPPER_ASSIGNMENTS + ("__defaults__", "__kwdefaults__")
#     328 )
#     329 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 330     return self(f, *args, **kw)
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/tenacity/__init__.py:467, in Retrying.__call__(self, fn, *args, **kwargs)
#     465 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     466 while True:
# --> 467     do = self.iter(retry_state=retry_state)
#     468     if isinstance(do, DoAttempt):
#     469         try:
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/tenacity/__init__.py:368, in BaseRetrying.iter(self, retry_state)
#     366 result = None
#     367 for action in self.iter_state.actions:
# --> 368     result = action(retry_state)
#     369 return result
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/tenacity/__init__.py:390, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     388 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     389     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 390         self._add_action_func(lambda rs: rs.outcome.result())
#     391         return
#     393     if self.after is not None:
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 if isinstance(do, DoAttempt):
#     469     try:
# --> 470         result = fn(*args, **kwargs)
#     471     except BaseException:  # noqa: B902
#     472         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/llms/openai/base.py:514, in OpenAI._complete(self, prompt, **kwargs)
#     511 self._update_max_tokens(all_kwargs, prompt)
#     513 if self.reuse_client:
# --> 514     response = client.completions.create(
#     515         prompt=prompt,
#     516         stream=False,
#     517         **all_kwargs,
#     518     )
#     519 else:
#     520     with client:
#
# File ~/.local/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/openai/resources/completions.py:528, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     499 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     500 def create(
#     501     self,
#    (...)
#     526     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     527 ) -> Completion | Stream[Completion]:
# --> 528     return self._post(
#     529         "/completions",
#     530         body=maybe_transform(
#     531             {
#     532                 "model": model,
#     533                 "prompt": prompt,
#     534                 "best_of": best_of,
#     535                 "echo": echo,
#     536                 "frequency_penalty": frequency_penalty,
#     537                 "logit_bias": logit_bias,
#     538                 "logprobs": logprobs,
#     539                 "max_tokens": max_tokens,
#     540                 "n": n,
#     541                 "presence_penalty": presence_penalty,
#     542                 "seed": seed,
#     543                 "stop": stop,
#     544                 "stream": stream,
#     545                 "stream_options": stream_options,
#     546                 "suffix": suffix,
#     547                 "temperature": temperature,
#     548                 "top_p": top_p,
#     549                 "user": user,
#     550             },
#     551             completion_create_params.CompletionCreateParams,
#     552         ),
#     553         options=make_request_options(
#     554             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     555         ),
#     556         cast_to=Completion,
#     557         stream=stream or False,
#     558         stream_cls=Stream[Completion],
#     559     )
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:1261, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1247 def post(
#    1248     self,
#    1249     path: str,
#    (...)
#    1256     stream_cls: type[_StreamT] | None = None,
#    1257 ) -> ResponseT | _StreamT:
#    1258     opts = FinalRequestOptions.construct(
#    1259         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1260     )
# -> 1261     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.local/lib/python3.11/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1048     stream_cls=stream_cls,
#    1049 )
#
# NotFoundError: 404 page not found

# %%
Settings.llm.complete("hi")
# Out:
# [_trace.py:45 - trace() ] connect_tcp.failed exception=KeyboardInterrupt()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Settings.llm.complete("hi")
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:223, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     219 self.span_enter(
#     220     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     221 )
#     222 try:
# --> 223     result = func(*args, **kwargs)
#     224 except BaseException as e:
#     225     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/core/llms/callbacks.py:389, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     380 event_id = callback_manager.on_event_start(
#     381     CBEventType.LLM,
#     382     payload={
#    (...)
#     386     },
#     387 )
#     388 try:
# --> 389     f_return_val = f(_self, *args, **kwargs)
#     390 except BaseException as e:
#     391     callback_manager.on_event_end(
#     392         CBEventType.LLM,
#     393         payload={EventPayload.EXCEPTION: e},
#     394         event_id=event_id,
#     395     )
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/site-packages/llama_index/llms/ollama/base.py:261, in Ollama.complete(self, prompt, formatted, **kwargs)
#     258     payload["format"] = "json"
#     260 with httpx.Client(timeout=Timeout(self.request_timeout)) as client:
# --> 261     response = client.post(
#     262         url=f"{self.base_url}/api/generate",
#     263         json=payload,
#     264     )
#     265     response.raise_for_status()
#     266     raw = response.json()
#
# File ~/.local/lib/python3.11/site-packages/httpx/_client.py:1132, in Client.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1111 def post(
#    1112     self,
#    1113     url: URLTypes,
#    (...)
#    1125     extensions: typing.Optional[RequestExtensions] = None,
#    1126 ) -> Response:
#    1127     """
#    1128     Send a `POST` request.
#    1129
#    1130     **Parameters**: See `httpx.request`.
#    1131     """
# -> 1132     return self.request(
#    1133         "POST",
#    1134         url,
#    1135         content=content,
#    1136         data=data,
#    1137         files=files,
#    1138         json=json,
#    1139         params=params,
#    1140         headers=headers,
#    1141         cookies=cookies,
#    1142         auth=auth,
#    1143         follow_redirects=follow_redirects,
#    1144         timeout=timeout,
#    1145         extensions=extensions,
#    1146     )
#
# File ~/.local/lib/python3.11/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.11/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.11/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.11/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.11/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File ~/.local/lib/python3.11/site-packages/httpx/_transports/default.py:218, in HTTPTransport.handle_request(self, request)
#     205 req = httpcore.Request(
#     206     method=request.method,
#     207     url=httpcore.URL(
#    (...)
#     215     extensions=request.extensions,
#     216 )
#     217 with map_httpcore_exceptions():
# --> 218     resp = self._pool.handle_request(req)
#     220 assert isinstance(resp.stream, typing.Iterable)
#     222 return Response(
#     223     status_code=resp.status,
#     224     headers=resp.headers,
#     225     stream=ResponseStream(resp.stream),
#     226     extensions=resp.extensions,
#     227 )
#
# File ~/.local/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:262, in ConnectionPool.handle_request(self, request)
#     260     with ShieldCancellation():
#     261         self.response_closed(status)
# --> 262     raise exc
#     263 else:
#     264     break
#
# File ~/.local/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:245, in ConnectionPool.handle_request(self, request)
#     242         raise exc
#     244 try:
# --> 245     response = connection.handle_request(request)
#     246 except ConnectionNotAvailable:
#     247     # The ConnectionNotAvailable exception is a special case, that
#     248     # indicates we need to retry the request on a new connection.
#    (...)
#     252     # might end up as an HTTP/2 connection, but which actually ends
#     253     # up as HTTP/1.1.
#     254     with self._pool_lock:
#     255         # Maintain our position in the request queue, but reset the
#     256         # status so that the request becomes queued again.
#
# File ~/.local/lib/python3.11/site-packages/httpcore/_sync/connection.py:69, in HTTPConnection.handle_request(self, request)
#      67 if self._connection is None:
#      68     try:
# ---> 69         stream = self._connect(request)
#      71         ssl_object = stream.get_extra_info("ssl_object")
#      72         http2_negotiated = (
#      73             ssl_object is not None
#      74             and ssl_object.selected_alpn_protocol() == "h2"
#      75         )
#
# File ~/.local/lib/python3.11/site-packages/httpcore/_sync/connection.py:117, in HTTPConnection._connect(self, request)
#     109     kwargs = {
#     110         "host": self._origin.host.decode("ascii"),
#     111         "port": self._origin.port,
#    (...)
#     114         "socket_options": self._socket_options,
#     115     }
#     116     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 117         stream = self._network_backend.connect_tcp(**kwargs)
#     118         trace.return_value = stream
#     119 else:
#
# File ~/.local/lib/python3.11/site-packages/httpcore/_backends/sync.py:100, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      94 exc_map: ExceptionMapping = {
#      95     socket.timeout: ConnectTimeout,
#      96     OSError: ConnectError,
#      97 }
#      99 with map_exceptions(exc_map):
# --> 100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#     105     for option in socket_options:
#     106         sock.setsockopt(*option)  # pragma: no cover
#
# File ~/mambaforge/envs/ml-gpu/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     834 if source_address:
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#     838 exceptions.clear()
#
# KeyboardInterrupt:
